# %%
pip install llama-index
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 816.5/816.5 kB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 51.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 77.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 18.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 5.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# ...

# %%
import os
os.environ["OPENAI_API_KEY"] = "YOUR-OPENAPI-KEY"

# %%
from llama_index import VectorStoreIndex, SimpleDirectoryReader
documents = SimpleDirectoryReader("/content/drive/MyDrive/LLaMa2 - ChatBOT/data").load_data()
index = VectorStoreIndex.from_documents(documents)
# Out:
# [nltk_data] Downloading package punkt to /tmp/llama_index...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
import os
os.environ["REPLICATE_API_TOKEN"] = "YOUR_REPLICATE_API_TOKEN"

# %%
from llama_index.llms import Replicate
llama2_7b_chat = "meta/llama-2-7b-chat:8e6975e5ed6174911a6ff3d60540dfd4844201974602551e10e9e87ab143d81e"
llm = Replicate(
    model=llama2_7b_chat,
    temperature=0.01,
    additional_kwargs={"top_p": 1, "max_new_tokens":300}
)

# %%
pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 40.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 35.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 101.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 89.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 33.6 MB/s eta 0:00:00
# ...

# %%
from llama_index.embeddings import HuggingFaceEmbedding
from llama_index import ServiceContext
embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")
service_context = ServiceContext.from_defaults(llm=llm, embed_model=embed_model)

# %%
from llama_index import VectorStoreIndex, SimpleDirectoryReader
documents = SimpleDirectoryReader("/content/drive/MyDrive/LLaMa2 - ChatBOT/data").load_data()
index = VectorStoreIndex.from_documents(documents)

# %%
query_engine = index.as_query_engine()
response = query_engine.query("What is the latest version of the YOLO algorithm")
print(response.response)
# Out:
# WARNING:llama_index.llms.openai_utils:Retrying llama_index.embeddings.openai.get_embedding in 0.5774840778193139 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-ATswVb6E5nMWRidJTt6MnChw on requests per min. Limit: 3 / min. Please try again in 20s. Visit https://platform.openai.com/account/rate-limits to learn more. You can increase your rate limit by adding a payment method to your account at https://platform.openai.com/account/billing..
# WARNING:llama_index.llms.openai_utils:Retrying llama_index.embeddings.openai.get_embedding in 0.48657363145201016 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-ATswVb6E5nMWRidJTt6MnChw on requests per min. Limit: 3 / min. Please try again in 20s. Visit https://platform.openai.com/account/rate-limits to learn more. You can increase your rate limit by adding a payment method to your account at https://platform.openai.com/account/billing..
# ...

# %%
query_engine = index.as_query_engine()
response = query_engine.query("YOLOv8 has various use cases in both object detection and image classification tasks. What are they?")
print(response.response)
# Out:
# YOLOv8 has various use cases in both object detection and image classification tasks. Some examples include autonomous vehicles, surveillance systems, retail stores, medical imaging, agriculture, and robotics.

# %%
import textwrap

# Your previous code to get the response
query_engine = index.as_query_engine()
response = query_engine.query("YOLOv8 has various use cases in both object detection and image classification tasks. What are they?")
text = response.response

# Define the width of the screen (adjust as needed)
screen_width = 80

# Wrap the text to fit the screen width
wrapped_text = textwrap.fill(text, width=screen_width)

# Print the wrapped text
print(wrapped_text)
# Out:
# YOLOv8 has various use cases in both object detection and image classification
# tasks. Some examples include autonomous vehicles, surveillance systems, retail
# stores, medical imaging, agriculture, and robotics.
